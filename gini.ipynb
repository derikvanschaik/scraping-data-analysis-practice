# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
# data downloaded from: https://data.worldbank.org/indicator/SI.POV.GINI?end=2019&start=2019&view=map
df = pd.read_csv( os.getcwd()+'\ginidata.csv' )

# %%
df.head()
# Out:
#          Data Source World Development Indicators  \
# 0                NaN                          NaN
# 1  Last Updated Date                    9/15/2021
# 2                NaN                          NaN
# 3       Country Name                 Country Code
# 4              Aruba                          ABW
#
#                          Unnamed: 2      Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0                               NaN             NaN         NaN         NaN
# 1                               NaN             NaN         NaN         NaN
# 2                               NaN             NaN         NaN         NaN
# 3                    Indicator Name  Indicator Code      1960.0      1961.0
# 4  Gini index (World Bank estimate)     SI.POV.GINI         NaN         NaN
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 55  \
# 0         NaN         NaN         NaN         NaN  ...          NaN
# 1         NaN         NaN         NaN         NaN  ...          NaN
# 2         NaN         NaN         NaN         NaN  ...          NaN
# 3      1962.0      1963.0      1964.0      1965.0  ...       2011.0
# 4         NaN         NaN         NaN         NaN  ...          NaN
#
#    Unnamed: 56  Unnamed: 57  Unnamed: 58  Unnamed: 59  Unnamed: 60  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3       2012.0       2013.0       2014.0       2015.0       2016.0
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 61  Unnamed: 62  Unnamed: 63  Unnamed: 64
# 0          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN
# 3       2017.0       2018.0       2019.0       2020.0
# 4          NaN          NaN          NaN          NaN
#
# [5 rows x 65 columns]

# %%
# We want to drop rows 0, 1, and 2 from the dataframe
df = df.drop([0, 1, 2])
df.head()
# Out:
#                    Data Source World Development Indicators  \
# 3                 Country Name                 Country Code
# 4                        Aruba                          ABW
# 5  Africa Eastern and Southern                          AFE
# 6                  Afghanistan                          AFG
# 7   Africa Western and Central                          AFW
#
#                          Unnamed: 2      Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 3                    Indicator Name  Indicator Code      1960.0      1961.0
# 4  Gini index (World Bank estimate)     SI.POV.GINI         NaN         NaN
# 5  Gini index (World Bank estimate)     SI.POV.GINI         NaN         NaN
# 6  Gini index (World Bank estimate)     SI.POV.GINI         NaN         NaN
# 7  Gini index (World Bank estimate)     SI.POV.GINI         NaN         NaN
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 55  \
# 3      1962.0      1963.0      1964.0      1965.0  ...       2011.0
# 4         NaN         NaN         NaN         NaN  ...          NaN
# 5         NaN         NaN         NaN         NaN  ...          NaN
# 6         NaN         NaN         NaN         NaN  ...          NaN
# 7         NaN         NaN         NaN         NaN  ...          NaN
#
#    Unnamed: 56  Unnamed: 57  Unnamed: 58  Unnamed: 59  Unnamed: 60  \
# 3       2012.0       2013.0       2014.0       2015.0       2016.0
# 4          NaN          NaN          NaN          NaN          NaN
# 5          NaN          NaN          NaN          NaN          NaN
# 6          NaN          NaN          NaN          NaN          NaN
# 7          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 61  Unnamed: 62  Unnamed: 63  Unnamed: 64
# 3       2017.0       2018.0       2019.0       2020.0
# 4          NaN          NaN          NaN          NaN
# 5          NaN          NaN          NaN          NaN
# 6          NaN          NaN          NaN          NaN
# 7          NaN          NaN          NaN          NaN
#
# [5 rows x 65 columns]

# %%
df.columns = df.iloc[0]
df = df.iloc[1: , :] # drop the first row as it is the same as our columns row 
df.head()
# Out:
# 3                 Country Name Country Code                    Indicator Name  \
# 4                        Aruba          ABW  Gini index (World Bank estimate)
# 5  Africa Eastern and Southern          AFE  Gini index (World Bank estimate)
# 6                  Afghanistan          AFG  Gini index (World Bank estimate)
# 7   Africa Western and Central          AFW  Gini index (World Bank estimate)
# 8                       Angola          AGO  Gini index (World Bank estimate)
#
# 3 Indicator Code  1960.0  1961.0  1962.0  1963.0  1964.0  1965.0  ...  2011.0  \
# 4    SI.POV.GINI     NaN     NaN     NaN     NaN     NaN     NaN  ...     NaN
# 5    SI.POV.GINI     NaN     NaN     NaN     NaN     NaN     NaN  ...     NaN
# 6    SI.POV.GINI     NaN     NaN     NaN     NaN     NaN     NaN  ...     NaN
# 7    SI.POV.GINI     NaN     NaN     NaN     NaN     NaN     NaN  ...     NaN
# 8    SI.POV.GINI     NaN     NaN     NaN     NaN     NaN     NaN  ...     NaN
#
# 3  2012.0  2013.0  2014.0  2015.0  2016.0  2017.0  2018.0  2019.0  2020.0
# 4     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 6     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 7     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 8     NaN     NaN     NaN     NaN     NaN     NaN    51.3     NaN     NaN
#
# [5 rows x 65 columns]

# %%
countries = pd.pivot_table(data=df,index=['Country Name'])
countries
# Out:
# 3                   1967.0  1969.0  1971.0  1974.0  1975.0  1978.0  1979.0  \
# Country Name
# Albania                NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Algeria                NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Angola                 NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Argentina              NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Armenia                NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...                    ...     ...     ...     ...     ...     ...     ...
# Vietnam                NaN     NaN     NaN     NaN     NaN     NaN     NaN
# West Bank and Gaza     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Yemen, Rep.            NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Zambia                 NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Zimbabwe               NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# 3                   1980.0  1981.0  1982.0  ...  2010.0  2011.0  2012.0  \
# Country Name                                ...
# Albania                NaN     NaN     NaN  ...     NaN     NaN    29.0
# Algeria                NaN     NaN     NaN  ...     NaN    27.6     NaN
# Angola                 NaN     NaN     NaN  ...     NaN     NaN     NaN
# Argentina             40.8     NaN     NaN  ...    43.6    42.6    41.3
# Armenia                NaN     NaN     NaN  ...    30.0    29.4    29.6
# ...                    ...     ...     ...  ...     ...     ...     ...
# Vietnam                NaN     NaN     NaN  ...    39.3     NaN    35.6
# West Bank and Gaza     NaN     NaN     NaN  ...    35.3    34.4     NaN
# Yemen, Rep.            NaN     NaN     NaN  ...     NaN     NaN     NaN
# Zambia                 NaN     NaN     NaN  ...    55.6     NaN     NaN
# Zimbabwe               NaN     NaN     NaN  ...     NaN    43.2     NaN
#
# 3                   2013.0  2014.0  2015.0  2016.0  2017.0  2018.0  2019.0
# Country Name
# Albania                NaN    34.6    32.9    33.7    33.2     NaN     NaN
# Algeria                NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Angola                 NaN     NaN     NaN     NaN     NaN    51.3     NaN
# Argentina             40.9    41.6     NaN    42.0    41.1    41.3    42.9
# Armenia               30.6    31.5    32.4    32.5    33.6    34.4    29.9
# ...                    ...     ...     ...     ...     ...     ...     ...
# Vietnam                NaN    34.8     NaN    35.3     NaN    35.7     NaN
# West Bank and Gaza     NaN     NaN     NaN    33.7     NaN     NaN     NaN
# Yemen, Rep.            NaN    36.7     NaN     NaN     NaN     NaN     NaN
# Zambia                 NaN     NaN    57.1     NaN     NaN     NaN     NaN
# Zimbabwe               NaN     NaN     NaN     NaN    44.3     NaN    50.3
#
# [167 rows x 47 columns]

# %%
ginis = {} # country name -> list of gini values 
for i in range(len(countries.index)):
    series = countries.iloc[i].dropna()
    ginis[series.name] = list( series )

# %%
def mean(list):
    return sum(list)/len(list)

ginis_mean = {}
for country, ginis_list in ginis.items():
    ginis_mean[country] = mean(ginis_list)

# get the top 10 highest gini mean 
top_10 = sorted(ginis_mean, key=ginis_mean.get, reverse=True)[:10]
top_10
# Out:
# ['South Africa',
#  'Namibia',
#  'Central African Republic',
#  'Botswana',
#  'Suriname',
#  'Belize',
#  'Brazil',
#  'Guatemala',
#  'Eswatini',
#  'Lesotho']

# %%
# plot the highest ginis to see how they have differed over the years 
#(remember the series data is chronological in df countries)
def plot(start_idx, end_idx):
    fig = plt.figure()
    ax = plt.axes()
    for country in top_10[start_idx:end_idx]:
        x = list(range(len(ginis[country])))
        y = ginis[country]
        ax.plot(x, y, label=country)
    ax.legend()
    
# split the plotting or else plots will be too crammed
plot(0, 5)
plot(5, -1)

# %%
# Interesting to observe that all gini indices are decreasing except for South Africa which has actually increased
# We want these gini indices to decrease -- singifies wealth inequality is decreasing in these countries

# %%
# I want to grab the last recorded Ginis of Each country and their respective year
ginis_latest = {} 
for i in range(len(countries.index)):
    series = countries.iloc[i].dropna()
    if len(series) > 0:
        ginis_latest[series.name] = (series.index.values[-1], series[-1]) # year, gini value

# %%
# from lowest latest gini to highest 
sorted_gini_latest = sorted(ginis_latest.items(), key = lambda x: x[1][1] )
highest_3 = sorted_gini_latest[-3:]
lowest_3 = sorted_gini_latest[:3]

# %%
fig = plt.figure()
ax = plt.axes()
countries = [country_info[0] for country_info in highest_3 + lowest_3]
ginis = [country_info[1][1] for country_info in highest_3 + lowest_3]
ax.bar(countries, ginis, color = ['light red' for i in range(3)] + ['light blue' for i in range(3)])
plt.xticks(rotation = 45) 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-3486299558cf> in <module>
#       3 countries = [country_info[0] for country_info in highest_3 + lowest_3]
#       4 ginis = [country_info[1][1] for country_info in highest_3 + lowest_3]
# ----> 5 ax.bar(countries, ginis, color = ['light red' for i in range(3)] + ['light blue' for i in range(3)])
#       6 plt.xticks(rotation = 45)
#       7 plt.show()
#
# ~\Documents\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\Documents\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2441
#    2442         linewidth = itertools.cycle(np.atleast_1d(linewidth))
# -> 2443         color = itertools.chain(itertools.cycle(mcolors.to_rgba_array(color)),
#    2444                                 # Fallback if color == "none".
#    2445                                 itertools.repeat('none'))
#
# ~\Documents\Anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba_array(c, alpha)
#     339         return np.zeros((0, 4), float)
#     340     else:
# --> 341         return np.array([to_rgba(cc, alpha) for cc in c])
#     342
#     343
#
# ~\Documents\Anaconda3\lib\site-packages\matplotlib\colors.py in <listcomp>(.0)
#     339         return np.zeros((0, 4), float)
#     340     else:
# --> 341         return np.array([to_rgba(cc, alpha) for cc in c])
#     342
#     343
#
# ~\Documents\Anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba(c, alpha)
#     187         rgba = None
#     188     if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 189         rgba = _to_rgba_no_colorcycle(c, alpha)
#     190         try:
#     191             _colors_full_map.cache[c, alpha] = rgba
#
# ~\Documents\Anaconda3\lib\site-packages\matplotlib\colors.py in _to_rgba_no_colorcycle(c, alpha)
#     258                     f"Value must be within 0-1 range")
#     259             return c, c, c, alpha if alpha is not None else 1.
# --> 260         raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     261     # tuple color.
#     262     if not np.iterable(c):
#
# ValueError: Invalid RGBA argument: 'light red'
